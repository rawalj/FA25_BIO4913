# %% [markdown]
# ### Work done in class, Nov 13th, 2025

# %%
# print to standard out
print ("Practicing printing")
# Out:
# Practicing printing

# %%
#set a variable equal to the integer 8
INTEGER=8
print(INTEGER)
# Out:
# 8

# %%
# multiple variables at once with esc chars
NAME="JUHI \n\t RAWAL"
print (INTEGER,NAME)
# Out:
# 8 JUHI
# 	 RAWAL

# %% [markdown]
# # LOOPS!!!

# %%
#learning
CODE = "CODE"
print (CODE[0])
print (CODE[1])
print (CODE[2])
print (CODE[3])
# Out:
# C
# O
# D
# E

# %% [markdown]
# Syntax of a loop
#
# For element in list/string run commands

# %%
# for element in string print each char
for char in CODE:
    print (char)
# Out:
# C
# O
# D
# E

# %%
# reset variable and print to confirm
NAME="JUHI"
print (NAME)
# Out:
# JUHI

# %%
COUNTER=0

for char in NAME: #do this for each char in name
    COUNTER= COUNTER+1 #increase counter by 1
print (f"There are {COUNTER} characters in my name") # use f to print with var
print ("There are", COUNTER, "characters in my name") # use cycling in and out of string
# Out:
# There are 4 characters in my name
# There are 4 characters in my name

# %% [markdown]
# ### len
#
# len creates ${#array[@]}

# %%
print(len(NAME))
#Nesting commands
LENGTH=len(NAME)
print(LENGTH)
# Out:
# 4
# 4

# %%
#before using len in a loop
for NUM in range (1,4):
    print(NUM)
# Out:
# 1
# 2
# 3

# %%
#Using len in a loop
LENGTH=len(NAME)
for NUM in range(LENGTH):
    print(NUM)
# Out:
# 0
# 1
# 2
# 3

# %%
J="JUHI"
for i in range (3): #for 0,1,2
    print(J[i])
# Out:
# J
# U
# H

# %%
FULLNAME="JUHI" +"RAWAL" #concat 2 strings
print (FULLNAME)

REVERSE=''
for CHAR in FULLNAME:
    REVERSE =CHAR +REVERSE

print (REVERSE)
# Out:
# JUHIRAWAL
# LAWARIHUJ

# %% [markdown]
# When I concatenate, the order of strings matters.

# %% [markdown]
# # Conditionals
#
# if, else, elif

# %%
AGE=19 #set var
if AGE>=18: #if the age is more or equal to 18
    print("adult")
elif 12<AGE<18:
    print ("teen")
else:
    print ("child")
# Out:
# adult

# %%
#read entire file using with open()
FILENAME= '/home/shared/FA25_coding/intro_files/letters.txt'
# Out:
#   Cell In[69], line 2
#     with open ('/home/shared/FA25_coding/intro_files/letters.txt'
#                                                                  ^
# SyntaxError: incomplete input
