# %% [markdown]
# # I'm making my ***first*** Jupyter Notebook!

# %%
print("This is my first notebook!")
# Out:
# This is my first notebook!

# %% [markdown]
# ## I LOVE MARKDOWN!!
# ### YIPPEE

# %% [markdown]
# Specifying my first variable, INTEGER, which has the value 12.

# %%
#set INTEGER to equal 12
INTEGER=8

# %%
print(INTEGER)
# Out:
# 12

# %%
#set floating poit to 12.0
FLOAT_PT=12.0

# %%
#print INTEGER and FLOAT_PT
print(INTEGER, FLOAT_PT)
# Out:
# 8 12.0

# %%
#set STRING 
STRING="The integer is"

# %%
print(STRING, INTEGER)
# Out:
# The integer is 8

# %%
#Print sum
print ("The sum is", INTEGER + FLOAT_PT)
# Out:
# The sum is 24.0

# %%
STRING2='THIS IS A STRING.\n\n\n'
STRING3="THIS IS \t\t\t ALSO A STRING."
print(STRING2,STRING3)
# Out:
# THIS IS A STRING.
#
#
#  THIS IS 			 ALSO A STRING.

# %% [markdown]
# ### APPLYING METHODS FOR THE FIRST TIME!!!!!!!!!!!

# %%
print(STRING)
# Out:
# The integer is

# %%
print(STRING.title())
# Out:
# The Integer Is

# %%
print(STRING.upper())
# Out:
# THE INTEGER IS

# %%
print(STRING.lower())
# Out:
# the integer is

# %%
#put a variable in a string!
print(f"The integer is {INTEGER}, my favorite integer".upper())
# Out:
# THE INTEGER IS 8, MY FAVORITE INTEGER

# %% [markdown]
# # IN CLASS EXERCISE

# %%
#set FIRST NAME to equal JUHI
FNAME="Juhi"

# %%
#set LAST NAME to equal RAWAl
LNAME="Rawal"

# %%
#set AGE to equal 21
AGE=21

# %%
INTRO=(f"My name is {FNAME} {LNAME} and I am {AGE} years old")

# %%
print(INTRO.upper())
# Out:
# MY NAME IS JUHI RAWAL AND I AM 21 YEARS OLD

# %% [markdown]
# # making list! 0 based like array

# %%
# create list
STUDENTS=['sariyah', 'elie', 'juhi', 'kena', 'lu', 'caroline', 'jon', 'shari', 'hasita']

# %%
#whom?
print(STUDENTS)
# Out:
# ['sariyah', 'elie', 'juhi', 'kena', 'lu', 'caroline', 'jon', 'shari', 'hasita']

# %%
#who's first?
print (STUDENTS [0])
# Out:
# sariyah

# %% [markdown]
# # nesting my lists

# %%
#create nested list
MY_NEST=[[1,2,3,4],['Juhi', 'has', 'a', 'cat'], ['Coding', 'is', 'life']]

# %%
#index into nested list
print (MY_NEST[0], MY_NEST[1], MY_NEST[2])
# Out:
# [1, 2, 3, 4] ['Juhi', 'has', 'a', 'cat'] ['Coding', 'is', 'life']

# %%
#index into indivual element in nested list
print("Coding is making me question my", MY_NEST[1][3])
# Out:
# Coding is making me question my cat

# %% [markdown]
# Lists are mutable. we can change them. I want to add to my list using append. and remove with pop!

# %%
#append method
STUDENTS.append('Brenna')
print(STUDENTS)
# Out:
# ['sariyah', 'elie', 'juhi', 'kena', 'lu', 'caroline', 'jon', 'shari', 'hasita', 'Brenna']

# %%
#pop method
POPPED=STUDENTS.pop(9)
print(STUDENTS)
# Out:
# ['sariyah', 'elie', 'juhi', 'kena', 'lu', 'caroline', 'jon', 'shari', 'hasita']

# %%
print(POPPED)
# Out:
# Brenna

# %% [markdown]
# Reverse order of list using reverse method.

# %%
#reverse method
STUDENTS.reverse()
print(STUDENTS)
# Out:
# ['hasita', 'shari', 'jon', 'caroline', 'lu', 'kena', 'juhi', 'elie', 'sariyah']

# %%
BALONEY='oscar' #new string var
BALONEY_LIST=[] #empty list
print(BALONEY)
print(BALONEY_LIST)
#balogna is intentionally misspelled because it's a fake word
# Out:
# oscar
# []

# %%
#loop thru string to make list
for CHAR in BALONEY: #for variable CHAR in the variable BALONEY
    BALONEY_LIST.append(CHAR)
#lack of indent ends loop
print(f"my baloney has a name! it's {BALONEY_LIST}.")
# Out:
# my baloney has a name! it's ['o', 's', 'c', 'a', 'r'].

# %%
print(FNAME) 
print('The first letter of my name is:', FNAME[0])
# Out:
# Juhi
# The first letter of my name is: J

# %%
#slicing many characters from a string at once
FULLNAME='Juhi Rawal'
print(FULLNAME)
NEW_FIRST=FULLNAME[0:4] #characters 0-3, not including 4
print(NEW_FIRST)
NEW_LAST=FULLNAME[5:10] #characters 5-9, not including 10
print(NEW_LAST)
# Out:
# Juhi Rawal
# Juhi
# Rawal

# %%
# slicing a list
ELEMENTS= [['fluorine','F'],
           ['chlorine','Cl'],
           ['helium', 'He']]
print(ELEMENTS)
#slice last 2
ELEMENTS[-2:]
# Out:
# [['fluorine', 'F'], ['chlorine', 'Cl'], ['helium', 'He']]
# [['chlorine', 'Cl'], ['helium', 'He']]
